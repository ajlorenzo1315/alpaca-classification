# %%
import pandas as pd



def load_and_compare(csv_path1, csv_path2, csv_path3):
    try:
        # Cargar los CSV
        df1 = pd.read_csv(csv_path1)
        df2 = pd.read_csv(csv_path2)
        df3 = pd.read_csv(csv_path3)

        # Asumiendo que la primera columna es el 'nombre del archivo'
        # y la segunda la 'clasificación', unir los DataFrames en base al nombre del archivo
        merged_df = pd.merge(df1, df2, on=df1.columns[0], suffixes=('_model1', '_model2'))
        merged_df = pd.merge(merged_df, df3, on=merged_df.columns[0])

        # Función para determinar la clase común o la más frecuente
        def common_or_frequent_class(row):
            classes = [row['class_model1'], row['class_model2'], row['class_model3']]
            if classes.count(classes[0]) == 3:
                return classes[0]  # Todos iguales
            return max(set(classes), key=classes.count)  # La más común

        # Función para determinar la clase común o la más frecuente
        def common_class(row):
            classes = [row['class_model1'], row['class_model2'], row['class_model3']]
            if classes.count(classes[0]) == 3:
                return classes[0]  # Todos iguales
            else:
                return 'None'  # La más común
            
        # Renombrar columnas para claridad
        merged_df.columns = ['file_name', 'class_model1', 'class_model2', 'class_model3']

        # Crear una nueva columna con las clasificaciones en una tupla
        merged_df['class_tuple'] = list(zip(merged_df['class_model1'], 
                                            merged_df['class_model2'], 
                                            merged_df['class_model3']))
        merged_df['common_or_frequent'] = merged_df.apply(common_or_frequent_class, axis=1)
        
        merged_df['common'] = merged_df.apply(common_class, axis=1)
        
        return merged_df

    except Exception as e:
        return str(e)
        

# Placeholder paths for the CSV files
csv_path1 = './EQUIPO_MESSI_variante_CONTIDO_ETIQUETAS.csv'
csv_path2 = './EQUIPO_MESSI_variante_SEN_PREPROCESAMENTO.csv'
csv_path3 = './Alpaca_variante_chatgpt.csv'

# Loading the CSV files into Pandas DataFrames
try:
    df1 = pd.read_csv(csv_path1)
    df2 = pd.read_csv(csv_path2)
    df3 = pd.read_csv(csv_path3)
    loaded = True
except Exception as e:
    error_message = str(e)
    loaded = False

loaded, error_message if not loaded else (df1.head(), df2.head(), df3.head())
# Out:
# (True,
#  (     docid predicted_class
#   0   wfqwne         student
#   1  wwisnmd           other
#   2  xlhpgzu           other
#   3    yghie         student
#   4   omvawb           other,
#        docid predicted_class
#   0   wfqwne         student
#   1  wwisnmd           other
#   2  xlhpgzu           other
#   3    yghie         student
#   4   omvawb           other,
#        docid predicted_class
#   0  aaclkul           other
#   1  aagelci           other
#   2  aangjmn           other
#   3   aawnpc           other
#   4  abdjgiz         student))

# %%
# Ejemplo de uso
result = load_and_compare(csv_path1, csv_path2, csv_path3)
result
# Out:
#      file_name class_model1 class_model2 class_model3  \
# 0       wfqwne      student      student      student
# 1      wwisnmd        other        other        other
# 2      xlhpgzu        other        other        other
# 3        yghie      student      student      student
# 4       omvawb        other        other        other
# ...        ...          ...          ...          ...
# 1654    umhdmc        staff        staff      faculty
# 1655   pfhqfrd       course       course       course
# 1656    ezpaic        other        other        other
# 1657    iwwwqw      faculty      faculty      faculty
# 1658   zupzrry        other        other        other
#
#                       class_tuple common_or_frequent   common
# 0     (student, student, student)            student  student
# 1           (other, other, other)              other    other
# 2           (other, other, other)              other    other
# 3     (student, student, student)            student  student
# 4           (other, other, other)              other    other
# ...                           ...                ...      ...
# 1654      (staff, staff, faculty)              staff     None
# 1655     (course, course, course)             course   course
# 1656        (other, other, other)              other    other
# 1657  (faculty, faculty, faculty)            faculty  faculty
# 1658        (other, other, other)              other    other
#
# [1659 rows x 7 columns]

# %%
result.to_csv('./result_comarative.csv', index=False)

# %%
for index, row in result.iterrows():
    print(row)
# Out:
# file_name                                  wfqwne
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 0, dtype: object
# file_name                           wwisnmd
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1, dtype: object
# file_name                           xlhpgzu
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 2, dtype: object
# file_name                                   yghie
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 3, dtype: object
# file_name                            omvawb
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 4, dtype: object
# file_name                          ryxpilnj
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 5, dtype: object
# file_name                          plwcqfga
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 6, dtype: object
# file_name                               mqfmt
# class_model1                           course
# class_model2                            other
# class_model3                           course
# class_tuple           (course, other, course)
# common_or_frequent                     course
# common                                   None
# Name: 7, dtype: object
# file_name                                  pzaevn
# class_model1                              student
# class_model2                              student
# class_model3                              faculty
# class_tuple           (student, student, faculty)
# common_or_frequent                        student
# common                                       None
# Name: 8, dtype: object
# file_name                                  mmtvoq
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 9, dtype: object
# file_name                                  xbccwj
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 10, dtype: object
# file_name                                   avemi
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 11, dtype: object
# file_name                              browzov
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 12, dtype: object
# file_name                          lbokfzil
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 13, dtype: object
# file_name                                   pkbni
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 14, dtype: object
# file_name                          emjhblgl
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 15, dtype: object
# file_name                            sndtbf
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 16, dtype: object
# file_name                            qvkigj
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 17, dtype: object
# file_name                                 xuime
# class_model1                            project
# class_model2                            project
# class_model3                              other
# class_tuple           (project, project, other)
# common_or_frequent                      project
# common                                     None
# Name: 18, dtype: object
# file_name                            sbzkac
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 19, dtype: object
# file_name                           yxzgihv
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 20, dtype: object
# file_name                                 fvuyfjv
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 21, dtype: object
# file_name                           kqohtbk
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 22, dtype: object
# file_name                                 vqshies
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 23, dtype: object
# file_name                            xdyech
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 24, dtype: object
# file_name                                   uiidp
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 25, dtype: object
# file_name                                  lkhsef
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 26, dtype: object
# file_name                                jsybmuwh
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 27, dtype: object
# file_name                             izktf
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 28, dtype: object
# file_name                          sxghcaoe
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 29, dtype: object
# file_name                            tfghbb
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 30, dtype: object
# file_name                           mgvpscd
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 31, dtype: object
# file_name                                 jyeyszb
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 32, dtype: object
# file_name                          fhalcyxq
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 33, dtype: object
# file_name                                  xgtpxl
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 34, dtype: object
# file_name                                byyxifzz
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 35, dtype: object
# file_name                                  skcbez
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 36, dtype: object
# file_name                                 yajcfiu
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 37, dtype: object
# file_name                              pyywwcr
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 38, dtype: object
# file_name                            tomluz
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 39, dtype: object
# file_name                             faprw
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 40, dtype: object
# file_name                               ihrpmc
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 41, dtype: object
# file_name                            ucomfn
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 42, dtype: object
# file_name                                  gkhact
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 43, dtype: object
# file_name                               aaclkul
# class_model1                            student
# class_model2                            student
# class_model3                              other
# class_tuple           (student, student, other)
# common_or_frequent                      student
# common                                     None
# Name: 44, dtype: object
# file_name                            qgzfwk
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 45, dtype: object
# file_name                              gbzlhhl
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 46, dtype: object
# file_name                                jdjamsls
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 47, dtype: object
# file_name                                   ysfrk
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 48, dtype: object
# file_name                                rfiabezw
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 49, dtype: object
# file_name                                livhw
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 50, dtype: object
# file_name                                  xmmhnp
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 51, dtype: object
# file_name                            jtahlq
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 52, dtype: object
# file_name                                jymnj
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 53, dtype: object
# file_name                           axgkxmj
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 54, dtype: object
# file_name                               xicjxs
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 55, dtype: object
# file_name                                 bxxlthi
# class_model1                              student
# class_model2                              faculty
# class_model3                              student
# class_tuple           (student, faculty, student)
# common_or_frequent                        student
# common                                       None
# Name: 56, dtype: object
# file_name                                wkqvj
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 57, dtype: object
# file_name                          mrqhsday
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 58, dtype: object
# file_name                           vszfsxc
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 59, dtype: object
# file_name                             meqmm
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 60, dtype: object
# file_name                           rntfgee
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 61, dtype: object
# file_name                                  epuimb
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 62, dtype: object
# file_name                           otbmgnv
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 63, dtype: object
# file_name                               nnccrkk
# class_model1                            student
# class_model2                            student
# class_model3                              other
# class_tuple           (student, student, other)
# common_or_frequent                      student
# common                                     None
# Name: 64, dtype: object
# file_name                                 bgxblaq
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 65, dtype: object
# file_name                                 tbztbzu
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 66, dtype: object
# file_name                                  wcjpbf
# class_model1                              project
# class_model2                              project
# class_model3                              project
# class_tuple           (project, project, project)
# common_or_frequent                        project
# common                                    project
# Name: 67, dtype: object
# file_name                            doihof
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 68, dtype: object
# file_name                                 qxxqr
# class_model1                              other
# class_model2                            project
# class_model3                            project
# class_tuple           (other, project, project)
# common_or_frequent                      project
# common                                     None
# Name: 69, dtype: object
# file_name                                   ncnaj
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 70, dtype: object
# file_name                                   vrnec
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 71, dtype: object
# file_name                           tjvzkyq
# class_model1                          staff
# class_model2                          staff
# class_model3                          staff
# class_tuple           (staff, staff, staff)
# common_or_frequent                    staff
# common                                staff
# Name: 72, dtype: object
# file_name                                lfuutmdo
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 73, dtype: object
# file_name                               altuxox
# class_model1                            student
# class_model2                              staff
# class_model3                            student
# class_tuple           (student, staff, student)
# common_or_frequent                      student
# common                                     None
# Name: 74, dtype: object
# file_name                            plbcxaf
# class_model1                           other
# class_model2                          course
# class_model3                           other
# class_tuple           (other, course, other)
# common_or_frequent                     other
# common                                  None
# Name: 75, dtype: object
# file_name                                 apakwv
# class_model1                               other
# class_model2                          department
# class_model3                               other
# class_tuple           (other, department, other)
# common_or_frequent                         other
# common                                      None
# Name: 76, dtype: object
# file_name                             qcaet
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 77, dtype: object
# file_name                                  sxdmgx
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 78, dtype: object
# file_name                                quatg
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 79, dtype: object
# file_name                                 ddurpci
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 80, dtype: object
# file_name                                 yloilxu
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 81, dtype: object
# file_name                           fmahjld
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 82, dtype: object
# file_name                             iqbqv
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 83, dtype: object
# file_name                             lfukf
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 84, dtype: object
# file_name                              rjkqlkz
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 85, dtype: object
# file_name                                 hchoacu
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              student
# class_tuple           (faculty, faculty, student)
# common_or_frequent                        faculty
# common                                       None
# Name: 86, dtype: object
# file_name                           ikgbbfg
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 87, dtype: object
# file_name                           ubpfdjg
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 88, dtype: object
# file_name                           eyjdhqq
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 89, dtype: object
# file_name                                  jnvplm
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 90, dtype: object
# file_name                             kydoocvs
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 91, dtype: object
# file_name                                         odgedcwl
# class_model1                                    department
# class_model2                                    department
# class_model3                                    department
# class_tuple           (department, department, department)
# common_or_frequent                              department
# common                                          department
# Name: 92, dtype: object
# file_name                          zgrzpiay
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 93, dtype: object
# file_name                           scfijbu
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 94, dtype: object
# file_name                            cfwzqt
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 95, dtype: object
# file_name                                  bwvavr
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 96, dtype: object
# file_name                                  ibxwya
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 97, dtype: object
# file_name                                 jwkygjy
# class_model1                              student
# class_model2                              faculty
# class_model3                              student
# class_tuple           (student, faculty, student)
# common_or_frequent                        student
# common                                       None
# Name: 98, dtype: object
# file_name                          fqkyhcel
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 99, dtype: object
# file_name                                wiozj
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 100, dtype: object
# file_name                                etibjjjs
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 101, dtype: object
# file_name                                alrywqkr
# class_model1                              project
# class_model2                              project
# class_model3                              project
# class_tuple           (project, project, project)
# common_or_frequent                        project
# common                                    project
# Name: 102, dtype: object
# file_name                                   rosxu
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 103, dtype: object
# file_name                                  bovyrx
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 104, dtype: object
# file_name                            eshbrq
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 105, dtype: object
# file_name                                isxcfiva
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 106, dtype: object
# file_name                                 suqfqzt
# class_model1                              project
# class_model2                              project
# class_model3                              project
# class_tuple           (project, project, project)
# common_or_frequent                        project
# common                                    project
# Name: 107, dtype: object
# file_name                                zgrtpsri
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 108, dtype: object
# file_name                          cjnxondy
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 109, dtype: object
# file_name                              feeuawp
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 110, dtype: object
# file_name                           bmmzflr
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 111, dtype: object
# file_name                               fxqhlu
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 112, dtype: object
# file_name                          augeudkf
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 113, dtype: object
# file_name                             lcuod
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 114, dtype: object
# file_name                                 xxnbrcs
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 115, dtype: object
# file_name                                 qtfpnpr
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 116, dtype: object
# file_name                            smqsgj
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 117, dtype: object
# file_name                                hurpsrje
# class_model1                              student
# class_model2                              faculty
# class_model3                              student
# class_tuple           (student, faculty, student)
# common_or_frequent                        student
# common                                       None
# Name: 118, dtype: object
# file_name                                 hmavwgj
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 119, dtype: object
# file_name                               jdnph
# class_model1                            staff
# class_model2                            staff
# class_model3                          student
# class_tuple           (staff, staff, student)
# common_or_frequent                      staff
# common                                   None
# Name: 120, dtype: object
# file_name                           saqelsg
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 121, dtype: object
# file_name                             wozzc
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 122, dtype: object
# file_name                              fkvuit
# class_model1                           course
# class_model2                            other
# class_model3                           course
# class_tuple           (course, other, course)
# common_or_frequent                     course
# common                                   None
# Name: 123, dtype: object
# file_name                           wqrxuql
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 124, dtype: object
# file_name                            caecfi
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 125, dtype: object
# file_name                             kvtlipjh
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 126, dtype: object
# file_name                                   oehiy
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 127, dtype: object
# file_name                                         gxabdahe
# class_model1                                    department
# class_model2                                    department
# class_model3                                    department
# class_tuple           (department, department, department)
# common_or_frequent                              department
# common                                          department
# Name: 128, dtype: object
# file_name                           qnsjufb
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 129, dtype: object
# file_name                                  sdyiaw
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 130, dtype: object
# file_name                             kuecr
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 131, dtype: object
# file_name                               mfdsqlg
# class_model1                              other
# class_model2                            student
# class_model3                            student
# class_tuple           (other, student, student)
# common_or_frequent                      student
# common                                     None
# Name: 132, dtype: object
# file_name                               qjjlm
# class_model1                            other
# class_model2                            other
# class_model3                          faculty
# class_tuple           (other, other, faculty)
# common_or_frequent                      other
# common                                   None
# Name: 133, dtype: object
# file_name                                rixsxfif
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 134, dtype: object
# file_name                             wrwst
# class_model1                          other
# class_model2                          other
# class_model3                          other
# ...
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1614, dtype: object
# file_name                               ciwmb
# class_model1                            other
# class_model2                          project
# class_model3                            other
# class_tuple           (other, project, other)
# common_or_frequent                      other
# common                                   None
# Name: 1615, dtype: object
# file_name                             pyiphyg
# class_model1                            staff
# class_model2                            staff
# class_model3                          student
# class_tuple           (staff, staff, student)
# common_or_frequent                      staff
# common                                   None
# Name: 1616, dtype: object
# file_name                             zlvjh
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1617, dtype: object
# file_name                           lclvhfy
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1618, dtype: object
# file_name                             wqydh
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1619, dtype: object
# file_name                          cqksepwt
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1620, dtype: object
# file_name                                   dmiti
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1621, dtype: object
# file_name                              gwnono
# class_model1                            other
# class_model2                          faculty
# class_model3                            other
# class_tuple           (other, faculty, other)
# common_or_frequent                      other
# common                                   None
# Name: 1622, dtype: object
# file_name                                  wzbokx
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 1623, dtype: object
# file_name                                 dxwljzj
# class_model1                              project
# class_model2                              project
# class_model3                              project
# class_tuple           (project, project, project)
# common_or_frequent                        project
# common                                    project
# Name: 1624, dtype: object
# file_name                                 rthigud
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1625, dtype: object
# file_name                                  btpdso
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 1626, dtype: object
# file_name                           kxckdvl
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1627, dtype: object
# file_name                                 uuzjjep
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1628, dtype: object
# file_name                          fuxozggi
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1629, dtype: object
# file_name                                          dxratuv
# class_model1                                    department
# class_model2                                    department
# class_model3                                    department
# class_tuple           (department, department, department)
# common_or_frequent                              department
# common                                          department
# Name: 1630, dtype: object
# file_name                                  junlpo
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1631, dtype: object
# file_name                             fhszf
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1632, dtype: object
# file_name                                   wuuif
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1633, dtype: object
# file_name                             dcidctu
# class_model1                            other
# class_model2                          faculty
# class_model3                            other
# class_tuple           (other, faculty, other)
# common_or_frequent                      other
# common                                   None
# Name: 1634, dtype: object
# file_name                             bdwiu
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1635, dtype: object
# file_name                                nefxpthf
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1636, dtype: object
# file_name                                  ryvuha
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 1637, dtype: object
# file_name                           xbczrmz
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1638, dtype: object
# file_name                          vplyymbb
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1639, dtype: object
# file_name                           cketrvj
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1640, dtype: object
# file_name                               lxqvv
# class_model1                            staff
# class_model2                          student
# class_model3                            staff
# class_tuple           (staff, student, staff)
# common_or_frequent                      staff
# common                                   None
# Name: 1641, dtype: object
# file_name                            ywpbst
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1642, dtype: object
# file_name                                  gfpmjx
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 1643, dtype: object
# file_name                                          jlkbszx
# class_model1                                    department
# class_model2                                    department
# class_model3                                    department
# class_tuple           (department, department, department)
# common_or_frequent                              department
# common                                          department
# Name: 1644, dtype: object
# file_name                          kqghrpia
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1645, dtype: object
# file_name                                 aigkvvw
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1646, dtype: object
# file_name                                 smkcife
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 1647, dtype: object
# file_name                             ixfhz
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1648, dtype: object
# file_name                                  wbqkmk
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 1649, dtype: object
# file_name                                   umqzp
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 1650, dtype: object
# file_name                                   tbugr
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1651, dtype: object
# file_name                                   aimch
# class_model1                              student
# class_model2                              student
# class_model3                              student
# class_tuple           (student, student, student)
# common_or_frequent                        student
# common                                    student
# Name: 1652, dtype: object
# file_name                                   sorah
# class_model1                              project
# class_model2                              project
# class_model3                              project
# class_tuple           (project, project, project)
# common_or_frequent                        project
# common                                    project
# Name: 1653, dtype: object
# file_name                              umhdmc
# class_model1                            staff
# class_model2                            staff
# class_model3                          faculty
# class_tuple           (staff, staff, faculty)
# common_or_frequent                      staff
# common                                   None
# Name: 1654, dtype: object
# file_name                              pfhqfrd
# class_model1                            course
# class_model2                            course
# class_model3                            course
# class_tuple           (course, course, course)
# common_or_frequent                      course
# common                                  course
# Name: 1655, dtype: object
# file_name                            ezpaic
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1656, dtype: object
# file_name                                  iwwwqw
# class_model1                              faculty
# class_model2                              faculty
# class_model3                              faculty
# class_tuple           (faculty, faculty, faculty)
# common_or_frequent                        faculty
# common                                    faculty
# Name: 1657, dtype: object
# file_name                           zupzrry
# class_model1                          other
# class_model2                          other
# class_model3                          other
# class_tuple           (other, other, other)
# common_or_frequent                    other
# common                                other
# Name: 1658, dtype: object

# %%
from sklearn.metrics import confusion_matrix

# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = result['common_or_frequent']
y_pred = df1['predicted_class']

# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred)

# %%
# Generate the confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import precision_score
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase

# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar

print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)
# Out:
# Precisión por clase: [1.         0.95121951 0.98611111 0.95046854 0.94845361 1.
#  0.96875   ]
# Precisión media total: 0.9721432531976631

# %%
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = result['common_or_frequent']
y_pred = df2['predicted_class']
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase

# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar

print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)
# Out:
# Precisión por clase: [0.93467337 0.95454545 0.93721973 0.96751412 0.86086957 0.70833333
#  0.96242775]
# Precisión media total: 0.9036547601186541

# %%
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = result['class_model1']
y_pred = result['class_model3']
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Precisión por clase: [0.93564356 0.88372093 0.88738739 0.94497937 0.82828283 0.36842105
#  0.89913545]
# Precisión media total: 0.8210815109770557

# %%
# Convertir a DataFrame para facilitar el filtrado
df = pd.DataFrame({'y_true': y_true, 'y_pred': y_pred})

# Filtrar las filas donde 'y_pred' es ''
df_filtered = df[df['y_true'] != 'None']

# Extraer de nuevo las listas después del filtrado
y_true_filtered = df_filtered['y_true'].tolist()
y_pred_filtered = df_filtered['y_pred'].tolist()
precisions = precision_score(y_true_filtered, y_pred_filtered, average=None)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true_filtered, y_pred_filtered, average='macro')  # 'macro' calcula la media sin ponderar
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)
# Out:
# Precisión por clase: [0.93564356 0.88372093 0.88738739 0.94497937 0.82828283 0.36842105
#  0.89913545]
# Precisión media total: 0.8210815109770557

# %%
# Comprobar si '' está en y_pred
valor_vacio_presente = "None" in y_true.unique()
valor_vacio_presente
# Out:
# False

# %%
y_true.unique()[2]
# Out:
# 'course'

# %%
df_filtered['y_true'].unique()
# Out:
# array(['student', 'other', 'course', 'faculty', 'project', 'staff',
#        'department'], dtype=object)

# %%
len(y_true_filtered)
# Out:
# 1659

# %%
len(y_true_filtered)/len(y_true)
# Out:
# 1.0

# %%
csv_path4 = './Alpaca_variante_2.csv'
df4 = pd.read_csv(csv_path3)
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = result['common_or_frequent']
y_pred = df4['predicted_class']

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = result['class_model1']
y_pred = result['class_model2']
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Precisión por clase: [0.90954774 0.86363636 0.91479821 0.9519774  0.74782609 0.54166667
#  0.92485549]
# Precisión media total: 0.8363297078129242

# %%
lista_file=['ckemt','igamsti','uqrfyv','gtchjnzw','apcgc','sphiqtdr','nwqios','lfukf','uihixqum','fhayg']
for name in lista_file:
    display(result[result['file_name']==name])
# Out:
#     file_name class_model1 class_model2 class_model3  \
# 641     ckemt      student      student      student
#
#                      class_tuple common_or_frequent   common
# 641  (student, student, student)            student  student
#      file_name class_model1 class_model2 class_model3  \
# 1470   igamsti       course       course       course
#
#                    class_tuple common_or_frequent  common
# 1470  (course, course, course)             course  course
#      file_name class_model1 class_model2 class_model3            class_tuple  \
# 1546    uqrfyv        other        other        other  (other, other, other)
#
#      common_or_frequent common
# 1546              other  other
#      file_name class_model1 class_model2 class_model3  \
# 1441  gtchjnzw      faculty      faculty      faculty
#
#                       class_tuple common_or_frequent   common
# 1441  (faculty, faculty, faculty)            faculty  faculty
#     file_name class_model1 class_model2 class_model3  \
# 587     apcgc      faculty      faculty      student
#
#                      class_tuple common_or_frequent common
# 587  (faculty, faculty, student)            faculty   None
#     file_name class_model1 class_model2 class_model3              class_tuple  \
# 907  sphiqtdr        other        other      student  (other, other, student)
#
#     common_or_frequent common
# 907              other   None
#      file_name class_model1 class_model2 class_model3  \
# 1322    nwqios      student      student      student
#
#                       class_tuple common_or_frequent   common
# 1322  (student, student, student)            student  student
#    file_name class_model1 class_model2 class_model3            class_tuple  \
# 84     lfukf        other        other        other  (other, other, other)
#
#    common_or_frequent common
# 84              other  other
#     file_name class_model1 class_model2 class_model3            class_tuple  \
# 579  uihixqum        other        other        other  (other, other, other)
#
#     common_or_frequent common
# 579              other  other
#      file_name class_model1 class_model2 class_model3  \
# 1507     fhayg      faculty      faculty      faculty
#
#                       class_tuple common_or_frequent   common
# 1507  (faculty, faculty, faculty)            faculty  faculty

# %%
lista_file=['ckemt','igamsti','uqrfyv','gtchjnzw','apcgc','sphiqtdr',]

# %%
path_rag='./resultados_rag1_test.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()

# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]

# %%
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
nuevo_df
# Out:
#    file_name class_model1 class_model2 class_model3  \
# 0      lfukf        other        other        other
# 1   ukgoagzq        other        other        other
# 2     kjjbbt        other        other        other
# 3   hpsaouip        other        other        other
# 4     egjrrq      student      student      student
# 5     yawspc      faculty      faculty      faculty
# 6    aktnyrw      student      student      student
# 7      rteuy        staff        staff        staff
# 8   pjnwjfgw      student      student      student
# 9    khtaydx      faculty      faculty      faculty
# 10  uihixqum        other        other        other
# 11     apcgc      faculty      faculty      student
# 12    uuyzux       course       course       course
# 13     ckemt      student      student      student
# 14   akbfdvs      student      student      student
# 15  sphiqtdr        other        other      student
# 16    oneaef      faculty      faculty        other
# 17    gotjzb        other        other        other
# 18    xyqyyd      faculty      faculty      faculty
# 19     pznqy        other        other        other
# 20    espxbh        other        other        other
# 21  pxcwhekn       course       course       course
# 22    nwqios      student      student      student
# 23  beveykcq        other        other        other
# 24  gtchjnzw      faculty      faculty      faculty
# 25   igamsti       course       course       course
# 26     fhayg      faculty      faculty      faculty
# 27    uqrfyv        other        other        other
# 28     wuuif      student      student      student
# 29     sorah      project      project      project
#
#                     class_tuple common_or_frequent   common predicted_class
# 0         (other, other, other)              other    other          course
# 1         (other, other, other)              other    other           other
# 2         (other, other, other)              other    other         student
# 3         (other, other, other)              other    other          course
# 4   (student, student, student)            student  student         student
# 5   (faculty, faculty, faculty)            faculty  faculty         faculty
# 6   (student, student, student)            student  student         student
# 7         (staff, staff, staff)              staff    staff           staff
# 8   (student, student, student)            student  student         student
# 9   (faculty, faculty, faculty)            faculty  faculty         faculty
# 10        (other, other, other)              other    other           other
# 11  (faculty, faculty, student)            faculty     None           staff
# 12     (course, course, course)             course   course          course
# 13  (student, student, student)            student  student         student
# 14  (student, student, student)            student  student         student
# 15      (other, other, student)              other     None         student
# 16    (faculty, faculty, other)            faculty     None         faculty
# 17        (other, other, other)              other    other         project
# 18  (faculty, faculty, faculty)            faculty  faculty         faculty
# 19        (other, other, other)              other    other         faculty
# 20        (other, other, other)              other    other         student
# 21     (course, course, course)             course   course          course
# 22  (student, student, student)            student  student         student
# 23        (other, other, other)              other    other           other
# 24  (faculty, faculty, faculty)            faculty  faculty         faculty
# 25     (course, course, course)             course   course          course
# 26  (faculty, faculty, faculty)            faculty  faculty         faculty
# 27        (other, other, other)              other    other         project
# 28  (student, student, student)            student  student         student
# 29  (project, project, project)            project  project          course

# %%
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Precisión por clase: [0.5        0.85714286 1.         0.         0.5        0.7       ]
# Precisión media total: 0.5928571428571429

# %%
path_rag='./resultados_rag1_test_1.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()
print(file_names)
# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
# Out:
# ['gotjzb' 'yawspc' 'uqrfyv' ... 'apkhal' 'vnibwn' 'cqyvoud']

# %%
nuevo_df
# Out:
#      file_name class_model1 class_model2 class_model3  \
# 0       wfqwne      student      student      student
# 1      wwisnmd        other        other        other
# 2      xlhpgzu        other        other        other
# 3        yghie      student      student      student
# 4       omvawb        other        other        other
# ...        ...          ...          ...          ...
# 1653    umhdmc        staff        staff      faculty
# 1654   pfhqfrd       course       course       course
# 1655    ezpaic        other        other        other
# 1656    iwwwqw      faculty      faculty      faculty
# 1657   zupzrry        other        other        other
#
#                       class_tuple common_or_frequent   common predicted_class
# 0     (student, student, student)            student  student         faculty
# 1           (other, other, other)              other    other         faculty
# 2           (other, other, other)              other    other          course
# 3     (student, student, student)            student  student         student
# 4           (other, other, other)              other    other          course
# ...                           ...                ...      ...             ...
# 1653      (staff, staff, faculty)              staff     None         faculty
# 1654     (course, course, course)             course   course          course
# 1655        (other, other, other)              other    other          course
# 1656  (faculty, faculty, faculty)            faculty  faculty         faculty
# 1657        (other, other, other)              other    other           staff
#
# [1658 rows x 8 columns]

# %%
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
print(len(y_true),len(y_pred))
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 1658 1658
# Precisión por clase: [0.36594912 0.4691358  0.48448687 0.94219653 0.26530612 0.02941176
#  0.74131274]
# Precisión media total: 0.47111413651582523

# %%
path_rag='./resultados_rag1_test_promt_2.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()
print(file_names)
# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
# Out:
# ['gotjzb' 'yawspc' 'uqrfyv' ... 'apkhal' 'vnibwn' 'cqyvoud']

# %%
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
print(len(y_true),len(y_pred))
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 1658 1658
# Precisión por clase: [0.51396648 0.68421053 0.49479167 0.73673036 0.43478261 0.032
#  0.77272727]
# Precisión media total: 0.5241727022552131

# %%
path_rag='./resultados_llm2_test_2_1.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()
print(file_names)
# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
print(len(y_true),len(y_pred))
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# ['gotjzb' 'yawspc' 'uqrfyv' 'gtchjnzw' 'aktnyrw' 'egjrrq' 'ukgoagzq'
#  'kjjbbt' 'igamsti' 'ckemt' 'apcgc' 'akbfdvs' 'sphiqtdr' 'hpsaouip'
#  'pznqy' 'beveykcq' 'uuyzux' 'sorah' 'nwqios' 'lfukf' 'uihixqum' 'espxbh'
#  'oneaef' 'wuuif' 'rteuy' 'khtaydx' 'xyqyyd' 'pxcwhekn' 'pjnwjfgw' 'fhayg'
#  'gyutr' 'xuoppkn' 'kxbknr' 'wognyts' 'gedcirqa' 'pbkzt' 'oovhs' 'szlmwq'
#  'vircjd' 'cdruyo' 'tnuwsmd' 'syphpwi' 'jwfzxxg' 'ppewcgla' 'crusceee'
#  'wzzsat' 'tibssnu' 'wwqvvjs' 'wsrchup' 'udghn' 'ihsbfi' 'ydbfhql'
#  'xxyuea' 'quatg' 'fczhavit' 'tbcbekmq' 'oecphzmr' 'xyiafjk' 'kcldhpcj'
#  'yvxpvlc' 'tpedb' 'wxbhjnn' 'ufsug' 'bhptsyjz' 'gxqadkgw' 'olbqqcm'
#  'debuzvc' 'ffcrqo' 'nlxxo' 'zvrysckq' 'jfqpd' 'tvmqpm' 'ouyuwu' 'boarhn'
#  'qvxwlws' 'xgtpxl' 'utthj' 'xvlikyt' 'wcwtzpny' 'eudatvy' 'jdwxv' 'qjjlm'
#  'czkze' 'quyjp' 'thxcjaib' 'wvhluq' 'brmtqcj' 'vxydxvhn' 'tbkoiw'
#  'zlshvea' 'woiup' 'rkokgno' 'yolbla' 'ujnnvh' 'rwrko' 'lclvhfy' 'meqmm'
#  'gjhhavd' 'cnlce' 'xegyoao' 'eyxtv' 'yftemp' 'idjfvfvk' 'cotsv'
#  'cjnrzzmk' 'xbywiofb' 'bofjb' 'ztoydtcl' 'ncnaj' 'macjz' 'kqghrpia'
#  'amwcmt' 'pobhzrg' 'ymako' 'rosxu' 'sfnmxx' 'jdscdzrq' 'lhyku' 'owvpwso'
#  'nttawca' 'ksglvhbn' 'uaalnyoj' 'aimch' 'uicnn' 'mgaymm' 'fvgngpl'
#  'plddbm' 'wzime' 'beoczxhp' 'lpzykg' 'titkmd' 'aagelci' 'pzidtqlv'
#  'pieuuqju' 'jewrlbk' 'iztxnf' 'rqbxxl' 'jcalgzyq' 'ijoyru' 'gfpmjx'
#  'ikgbbfg' 'omvawb' 'mfkaijyg' 'uraxyoec' 'fgnuh' 'xxnbrcs' 'qajnzy'
#  'bhzijblm' 'utvxb' 'sxfkrscz' 'aplafmip' 'ciwmb' 'fugmzdml' 'gwtwpgzd'
#  'iplufn' 'ttjwn' 'ynozhbm' 'ryvjcfnj' 'oyuuo' 'avemi' 'zlvjh' 'esxrrht'
#  'usnst' 'xggyx' 'pkvviu' 'bjzfnftw' 'ticyp' 'fxqhlu' 'oouybbn' 'caaelf'
#  'xpajbs' 'gnrotudd' 'urmpyj' 'cbuuznl' 'dbtooseb' 'thpiz' 'dyruktbc'
#  'jpxvffy' 'bcsrsbug' 'kfbgivtc' 'urgmrkp' 'alrywqkr' 'ekwtr' 'ixslka'
#  'fvcnksd' 'dhtdvz' 'ztrfkwki' 'hmidet' 'ovtoilww' 'evwphope' 'irhvprt'
#  'jqbbor' 'sdwkztnc' 'gwytgt' 'tfggglf' 'bvabh' 'oikri' 'uxdouy' 'icptqhh'
#  'caecfi' 'aljsfwq' 'fimnwyjw' 'ciuipt' 'ovfkp' 'owlrody' 'wkbpmmx'
#  'bmmzflr' 'zhwcpf' 'lcnosc' 'vukoi' 'hhabfel' 'ibnqs' 'hkdkgy' 'rpidkd'
#  'rcdphl' 'izhzil' 'eyaswbjz' 'bfiznf' 'qrbuxab' 'cqqqjx' 'haifof'
#  'amzuns' 'qruaqyip' 'tslgebal' 'iyemmjpt' 'kxwsy' 'ondlxia' 'xyufofwi'
#  'wdmhyym' 'nzoti' 'zgrtpsri' 'cjnxondy' 'uoqfwcge' 'kvals' 'qtdrqcai'
#  'bqfbagmb' 'qtwwz' 'metwifo' 'hhsnp' 'lmobyly' 'brwup' 'gfvefxbu' 'mbfpm'
#  'uphoqmv' 'unxkz' 'swgied' 'kztyatd' 'vbefiwn' 'duhyq' 'xigmw' 'gaqepyeo'
#  'tbztbzu' 'bpxla' 'xwgndfxh' 'qnoufgn' 'wjikmk' 'stfmt' 'ztmcj' 'mphlxz'
#  'ynikxrtr' 'tfghbb' 'wbxnhayf' 'smkcife' 'rtdhifk' 'rdhezzsl' 'tclywy'
#  'qfzzfcr' 'immpx' 'apnbs' 'igswa' 'xbccwj' 'qxdrhk' 'wjwnoa' 'ijsqaud'
#  'snkofs' 'pyepcme' 'pmtwul' 'uzmbjytx' 'tzabfv' 'lxvgk' 'mziqqxrl'
#  'pdkbg' 'duztbzxs' 'pbgmp' 'simnaiid' 'bxxlthi' 'lzqgc' 'eporowdg'
#  'vvzcwkr' 'iuxtwgjz' 'pdmah' 'jptfm' 'qhaov' 'dqxgzzq' 'syzkp' 'cgjuowc'
#  'zndgv' 'imltuesr' 'xlmkr' 'lgzaacv' 'uxhlojgi' 'smqmlfgn' 'ahomx'
#  'whchrj' 'qetmh' 'asani' 'vszfsxc' 'deqwxxpt' 'tnfeezvd' 'nbvsh' 'jhptp'
#  'tzloz' 'btrlegkg' 'ojpivf' 'ixfhz' 'ziuunycb' 'lbiaen' 'yqium' 'jdnph'
#  'aqsrcsy' 'kyughy' 'qobxesvq' 'lgztt' 'tjxmtdv' 'nfntx' 'gtwhcjns'
#  'lzybo' 'tsceov' 'uazvhld' 'moesglp' 'sxghcaoe' 'qtfpnpr' 'txetad'
#  'psenda' 'ffrkhfcp' 'vxwschv' 'txnig' 'roisjft' 'smffe' 'faprw'
#  'urpxexkq' 'umhdmc' 'flgtpxn' 'wuptba' 'mmizx' 'ucqabpbo' 'qysqqr'
#  'zjggyij' 'jfdjl' 'phbez' 'doihof' 'kgtrkmsz' 'uwnkyw' 'uvdoelf' 'nfdrma'
#  'gnaju' 'appjcc' 'pyywwcr' 'hvstwh' 'pnurvmuj' 'cifmtm' 'livhw'
#  'tzkasqnn' 'urhjkm' 'tnjlwzwb' 'xvzmwpsh' 'tzzky' 'bgudhc' 'bbgkx'
#  'nwsqesmo' 'umqzp' 'weuyrc' 'prlhb' 'dmiti' 'lvqkyij' 'pmmpv' 'pfhqfrd'
#  'isxcfiva' 'rngiu' 'ewlew' 'kegru' 'qmbrbf' 'tqofkoq' 'lbokfzil'
#  'zhncldpt' 'twfqhbrg' 'ffczrnz' 'flectkq' 'aiqltd' 'rthigud' 'gtdarzt'
#  'mzajvh' 'xwdvabs' 'khcaied' 'ldwnvwx' 'lzooyy' 'aaclkul' 'tibnwoka'
#  'ewsktq' 'ycvkbx' 'wisos' 'bttjq' 'jzifdoy']
# 403 403
# Precisión por clase: [0.56578947 0.5        0.47619048 0.8018018  0.38095238 0.05454545
#  0.7037037 ]
# Precisión media total: 0.49756904155400405

# %% [markdown]
# # -
#
# ```python
#
# def get_file_2(path_file):
#   #print(path_file)
#   with open(path_file) as f:
#       data = json.load(f)
#   #print(data.keys())
#   dict_text={key: data[key] for key in data.keys() if key in {'title','summary','links'} }
#   try:
#     dict_text['keyword']=data['keyword_frequency_kebert']
#   except:
#     print(data.keys())
#   return dict_text,data['ground_truth']
#
# def creating_promt_3(class_name,text_traindata,text_classification,keywords):
#   class_name=(', ').join(class_name)
#   text_traindata = ('\n\n').join([f" Text:'{text}' \n Classification: {label}" for text,label in text_traindata])
#   palabras_clave = ('\n').join([f"{label} keywords are {keys} " for label,keys in keywords])
#   return f" Classify the text in this class : {class_name}.\n\
#   Reply with only one word:  {class_name}. \n\
#   {palabras_clave} \n\n \
#   Examples: \n\
#   {text_traindata} \n\n\
#   Text: '{text_classification}' \n\
#   Classification: "
#
#     ```
#
# Model llama2-chat-ayb-13b.Q5_K_M.gguf

# %%
path_rag='./resultados_llm2_test_2_2.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()
print(file_names)
# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
print(len(y_true),len(y_pred))
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# ['gotjzb' 'yawspc' 'uqrfyv' ... 'apkhal' 'vnibwn' 'cqyvoud']
# 1658 1658
# Precisión por clase: [0.5280236  0.625      0.47420147 0.73248408 0.44047619 0.03524229
#  0.79591837]
# Precisión media total: 0.5187637140038116

# %% [markdown]
# # -
#
# ```python
#
# def get_file_2(path_file):
#   #print(path_file)
#   with open(path_file) as f:
#       data = json.load(f)
#   #print(data.keys())
#   dict_text={key: data[key] for key in data.keys() if key in {'title','summary','links'} }
#   try:
#     dict_text['keyword']=data['keyword_frequency_kebert']
#   except:
#     print(data.keys())
#   return dict_text,data['ground_truth']
#
# def creating_promt_3(class_name,text_traindata,text_classification,keywords):
#   class_name=(', ').join(class_name)
#   text_traindata = ('\n\n').join([f" Text:'{text}' \n Classification: {label}" for text,label in text_traindata])
#   palabras_clave = ('\n').join([f"{label} keywords are {keys} " for label,keys in keywords])
#   return f" Classify the text in this class : {class_name}.\n\
#   Reply with only one word:  {class_name}. \n\
#   {palabras_clave} \n\n \
#   Examples: \n\
#   {text_traindata} \n\n\
#   Text: '{text_classification}' \n\
#   Classification: "
#
#     ```

# %%
path_rag='./resultados_llm2_promt_2_model_mistral-7b-v0.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()
print(file_names)
# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
print(len(y_true),len(y_pred))
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None,labels=class_names)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print(class_names)
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# ['gtchjnzw' 'aktnyrw' 'egjrrq' 'ckemt' 'apcgc' 'akbfdvs' 'sphiqtdr'
#  'hpsaouip' 'pznqy' 'beveykcq' 'uuyzux' 'gotjzb' 'yawspc' 'uqrfyv'
#  'ukgoagzq' 'kjjbbt' 'igamsti' 'sorah' 'nwqios' 'lfukf' 'uihixqum'
#  'espxbh' 'oneaef' 'wuuif' 'rteuy' 'khtaydx' 'xyqyyd' 'pxcwhekn'
#  'pjnwjfgw' 'fhayg' 'gyutr' 'xuoppkn' 'kxbknr' 'wognyts' 'gedcirqa'
#  'pbkzt' 'oovhs' 'szlmwq' 'vircjd' 'cdruyo' 'tnuwsmd' 'syphpwi' 'jwfzxxg'
#  'ppewcgla' 'crusceee' 'wzzsat' 'tibssnu' 'wwqvvjs' 'wsrchup' 'udghn'
#  'ihsbfi' 'ydbfhql' 'xxyuea' 'quatg' 'fczhavit' 'tbcbekmq' 'oecphzmr'
#  'xyiafjk' 'kcldhpcj' 'yvxpvlc' 'tpedb' 'wxbhjnn' 'ufsug' 'bhptsyjz'
#  'gxqadkgw' 'olbqqcm' 'debuzvc' 'ffcrqo' 'nlxxo' 'zvrysckq' 'jfqpd'
#  'tvmqpm' 'ouyuwu' 'boarhn' 'qvxwlws' 'xgtpxl' 'utthj' 'xvlikyt'
#  'wcwtzpny' 'eudatvy' 'jdwxv' 'qjjlm' 'czkze' 'quyjp' 'thxcjaib' 'wvhluq'
#  'brmtqcj' 'vxydxvhn' 'tbkoiw' 'zlshvea' 'woiup' 'rkokgno' 'yolbla'
#  'ujnnvh' 'rwrko' 'lclvhfy' 'meqmm' 'gjhhavd' 'cnlce' 'xegyoao' 'eyxtv'
#  'yftemp' 'idjfvfvk' 'cotsv' 'cjnrzzmk' 'xbywiofb' 'bofjb' 'ztoydtcl'
#  'ncnaj' 'macjz' 'kqghrpia' 'amwcmt' 'pobhzrg' 'ymako' 'rosxu' 'sfnmxx'
#  'jdscdzrq' 'lhyku' 'owvpwso' 'nttawca' 'ksglvhbn' 'uaalnyoj' 'aimch'
#  'uicnn' 'mgaymm' 'fvgngpl' 'plddbm' 'wzime' 'beoczxhp' 'lpzykg' 'titkmd'
#  'aagelci' 'pzidtqlv' 'pieuuqju' 'jewrlbk' 'iztxnf' 'rqbxxl' 'jcalgzyq'
#  'ijoyru' 'gfpmjx' 'ikgbbfg' 'omvawb' 'mfkaijyg' 'uraxyoec' 'fgnuh'
#  'xxnbrcs' 'qajnzy' 'bhzijblm' 'utvxb' 'sxfkrscz' 'aplafmip' 'ciwmb'
#  'fugmzdml' 'gwtwpgzd' 'iplufn' 'ttjwn' 'ynozhbm' 'ryvjcfnj' 'oyuuo'
#  'avemi' 'zlvjh' 'esxrrht' 'usnst' 'xggyx' 'pkvviu' 'bjzfnftw' 'ticyp'
#  'fxqhlu' 'oouybbn' 'caaelf' 'xpajbs' 'gnrotudd' 'urmpyj' 'cbuuznl'
#  'dbtooseb' 'thpiz' 'dyruktbc' 'jpxvffy' 'bcsrsbug' 'kfbgivtc' 'urgmrkp'
#  'alrywqkr' 'ekwtr' 'ixslka' 'fvcnksd' 'dhtdvz' 'ztrfkwki' 'hmidet'
#  'ovtoilww' 'evwphope' 'irhvprt' 'jqbbor' 'sdwkztnc' 'gwytgt' 'tfggglf'
#  'bvabh' 'oikri' 'uxdouy' 'icptqhh' 'caecfi' 'aljsfwq' 'fimnwyjw' 'ciuipt'
#  'ovfkp' 'owlrody' 'wkbpmmx' 'bmmzflr' 'zhwcpf' 'lcnosc' 'vukoi' 'hhabfel'
#  'ibnqs' 'hkdkgy' 'rpidkd' 'rcdphl' 'izhzil' 'eyaswbjz' 'bfiznf' 'qrbuxab'
#  'cqqqjx' 'haifof' 'amzuns' 'qruaqyip' 'tslgebal' 'iyemmjpt' 'kxwsy'
#  'ondlxia' 'xyufofwi' 'wdmhyym' 'nzoti' 'zgrtpsri' 'cjnxondy' 'uoqfwcge'
#  'kvals' 'qtdrqcai' 'bqfbagmb' 'qtwwz' 'metwifo' 'hhsnp' 'lmobyly' 'brwup'
#  'gfvefxbu' 'mbfpm' 'uphoqmv' 'unxkz' 'swgied' 'kztyatd' 'vbefiwn' 'duhyq'
#  'xigmw' 'gaqepyeo' 'tbztbzu' 'bpxla' 'xwgndfxh' 'qnoufgn' 'wjikmk'
#  'stfmt' 'ztmcj' 'mphlxz' 'ynikxrtr' 'tfghbb' 'wbxnhayf' 'smkcife'
#  'rtdhifk' 'rdhezzsl' 'tclywy' 'qfzzfcr' 'immpx' 'apnbs' 'igswa' 'xbccwj'
#  'qxdrhk' 'wjwnoa' 'ijsqaud' 'snkofs' 'pyepcme' 'pmtwul' 'uzmbjytx'
#  'tzabfv' 'lxvgk' 'mziqqxrl' 'pdkbg' 'duztbzxs' 'pbgmp' 'simnaiid'
#  'bxxlthi' 'lzqgc' 'eporowdg' 'vvzcwkr' 'iuxtwgjz' 'pdmah' 'jptfm' 'qhaov'
#  'dqxgzzq' 'syzkp' 'cgjuowc' 'zndgv' 'imltuesr' 'xlmkr' 'lgzaacv'
#  'uxhlojgi' 'smqmlfgn' 'ahomx' 'whchrj' 'qetmh' 'asani' 'vszfsxc'
#  'deqwxxpt' 'tnfeezvd' 'nbvsh' 'jhptp' 'tzloz' 'btrlegkg' 'ojpivf' 'ixfhz'
#  'ziuunycb' 'lbiaen' 'yqium' 'jdnph' 'aqsrcsy' 'kyughy' 'qobxesvq' 'lgztt'
#  'tjxmtdv' 'nfntx' 'gtwhcjns' 'lzybo' 'tsceov' 'uazvhld' 'moesglp'
#  'sxghcaoe' 'qtfpnpr' 'txetad' 'psenda' 'ffrkhfcp' 'vxwschv' 'txnig'
#  'roisjft' 'smffe' 'faprw' 'urpxexkq' 'umhdmc' 'flgtpxn']
# 358 358
# ['student' 'other' 'course' 'faculty' 'project' 'staff' 'department']
# Precisión por clase: [0.65957447 0.91836735 0.52542373 0.62790698 0.3        0.06451613
#  0.35294118]
# Precisión media total: 0.49267568944063905

# %% [markdown]
# alpaca-classification/not_git/comparative/promt_3_r/resultados_llm2_test_promt_3llama2-chat-ayb-13b.Q5_K_M.csv

# %% [markdown]
# # -
# ```python
#
# def get_file_2(path_file):
#   #print(path_file)
#   with open(path_file) as f:
#       data = json.load(f)
#   #print(data.keys())
#   dict_text={key: data[key] for key in data.keys() if key in {'title','summary','links'} }
#   try:
#     dict_text['keyword']=data['keyword_frequency_kebert']
#   except:
#     print(data.keys())
#   return dict_text,data['ground_truth']
#
# def creating_promt_5(class_name,text_traindata,text_classification,keywords):
#   # quitamos other de los ejemplos y dejamos que sea como todo lo que no tenga clase como otro
#   class_name=(', ').join(class_name)
#   text_traindata = ('\n\n').join([f" Text:'{tranform_text(text)}' \n class: {label}" for text,label in text_traindata if label!='other'])
#   palabras_clave = ('\n').join([f"{label} keywords are {keys} " for label,keys in keywords])
#   return f" Classify  text into one of 7 class : {class_name}.\n\
#   Reply with only one word:  {class_name}. \n\
#   {palabras_clave} \n\n \
#   Examples: \n\
#   {text_traindata} \n\n\
#   Text: '{tranform_text(text_classification)}' \n\
#   class: "
#
#     ```
#
# Como se observa lo que se intenta es un nuevo promt para ver que tal se comporta  ./promt_3_r/resultados_llm2_test_promt_3llama2-chat-ayb-13b.Q5_K_M.csv

# %%
path_rag='./promt_3_r/resultados_llm2_test_promt_3llama2-chat-ayb-13b.Q5_K_M.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()
#print(file_names)
# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
print(len(y_true),len(y_pred))
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None,labels=class_names)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print(class_names)
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 1658 1658
# ['student' 'other' 'course' 'faculty' 'project' 'staff' 'department']
# Precisión por clase: [0.75438596 0.83684211 0.41214751 0.59677419 0.38216561 0.03311258
#  0.49253731]
# Precisión media total: 0.501137895779522

# %% [markdown]
# Vamos a almacenar que esta mal empecemos por las clases que peores resultados se obtiene en este caso vemos que es staff

# %%
# Filtrar el DataFrame para obtener las filas donde la predicción es 'staff' y la etiqueta verdadera es 'student'
staff_predicted_students = nuevo_df[
    (nuevo_df['predicted_class'] == 'staff') & (nuevo_df['class_model1'] == 'student')
]

# Extraer los nombres de los archivos de estas filas
staff_predicted_student_files = staff_predicted_students['file_name'].tolist()

len(staff_predicted_student_files)

# Extraer los nombres de los archivos de estas filas
staff_predicted_student_files = staff_predicted_students['file_name'].tolist()

# Guardar los nombres de los archivos en un archivo txt separado por comas
path_to_txt = 'staff_predicted_student_files.txt'
with open(path_to_txt, 'w') as f:
    f.write(','.join(staff_predicted_student_files))

# %%
# Cargar los nombres de archivo del archivo txt y almacenarlos en una lista
with open(path_to_txt, 'r') as f:
    loaded_files = f.read().split(',')

print(loaded_files)
# Out:
# ['wfqwne', 'pzaevn', 'mmtvoq', 'uiidp', 'byyxifzz', 'aaclkul', 'jdjamsls', 'ysfrk', 'xmmhnp', 'nnccrkk', 'bgxblaq', 'tbztbzu', 'lfuutmdo', 'ibxwya', 'bovyrx', 'xxnbrcs', 'hurpsrje', 'sdyiaw', 'cifyk', 'qjimegkq', 'qfxbal', 'xbazlov', 'mdfbugu', 'egjrrq', 'xiwqo', 'ticyp', 'zobjoz', 'utcniycx', 'gdxmso', 'cbdxh', 'xlmkr', 'vgkqf', 'upzow', 'uapyjabq', 'aktnyrw', 'laazymrn', 'qraso', 'nlxxo', 'fhwlo', 'qxdrhk', 'niizdbw', 'pbgmp', 'pkxxb', 'xhokpp', 'gtgxgzcn', 'muncc', 'wuuosaed', 'xfyqrgf', 'nmhpr', 'qtwwz', 'uypqg', 'zvrysckq', 'ekauzlfp', 'caaelf', 'owlrody', 'irhvprt', 'yadbhst', 'rwmiz', 'ywrzvbyr', 'goxgfr', 'ckemt', 'jryqezxd', 'ypxfdn', 'tkkhe', 'vtgaqhef', 'xefhoj', 'ylwraohb', 'llsokyh', 'dhrezf', 'kypnmal', 'utvxb', 'ghxnl', 'lexfksko', 'redifgfj', 'zwcgsbo', 'olyhatok', 'uxhlojgi', 'hyutx', 'hmidet', 'udfqv', 'zemgq', 'rbylaaw', 'qnoufgn', 'lynsj', 'pspktcof', 'ddlpfjed', 'lcnosc', 'uncjwyyp', 'kgaxenm', 'dqxgzzq', 'snkofs', 'tciwtsu', 'qrbuxab', 'vofqtp', 'nizpnfpt', 'lgztt', 'itmbdhy', 'biaio', 'qajnzy', 'vmtkvyq', 'rqdpssq', 'ygqsjtxz', 'xxyuea', 'gduwb', 'tyflylsk', 'qxuwjkk', 'prhhoulq', 'vwuwqyt', 'tzkasqnn', 'clcydbp', 'nwqios', 'ygycaic', 'wbuul', 'oosiq', 'iczwhz', 'sbswsnik', 'mmigvvwa', 'zcjqp', 'deopslyp', 'lxgov', 'tnjlwzwb', 'thpiz', 'rnosomvv', 'mfpqw', 'vlpbgmh', 'pnblr', 'fmqwylsg', 'yzqkk', 'dyzbzmd', 'gbvqwbe', 'spksfaj', 'kaqaica', 'wjikmk', 'rjukv', 'uuzjjep', 'nefxpthf', 'aimch']

# %% [markdown]
# # -
# "Prompt": "prmpt3 (keys)",
#
# "Tiempo": "[1:14:33<00:00, 3.58s/it]",
#
# "Modelo": "llama2-chat-ayb-13b.Q5_K_M.gguf"

# %%
path_rag='./Resultados_Abraham/Nuevos_Resultados/resultados_2023-11-19_12-38-53.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()
#print(file_names)
# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
print(len(y_true),len(y_pred))
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None,labels=class_names)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print(class_names)
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 1659 1659
# []
# Precisión por clase: []
# Precisión media total: 0.3348615045114481

# %% [markdown]
# # -
# "Prompt": "prmpt3 (keys)",
#
# "Tiempo": "[16:24:41<00:00, 3.58s/it]",
#
# "Modelo": "llama-2-70b-chat.Q3_K_S.gguf"

# %%
path_rag='./Resultados_Abraham/Nuevos_Resultados/resultados_2023-11-20_02-39-31.csv'
sub_df = pd.read_csv(path_rag)
# Paso 1: Extraer los nombres de archivo del sub-DataFrame
file_names = sub_df['file_name'].unique()
#print(file_names)
# Paso 2: Filtrar el DataFrame principal para estos nombres de archivo
df_filtrado = result[result['file_name'].isin(file_names)]
# Unir df_principal y sub_df en base a 'file_name'
nuevo_df = pd.merge(df_filtrado, sub_df, on='file_name', suffixes=('_principal', '_sub'))
# Asumiendo que las columnas de etiquetas se llaman 'true_label' y 'predicted_label'
y_true = nuevo_df['class_model1']
y_pred = nuevo_df['predicted_class']
print(len(y_true),len(y_pred))
# Calcular la precisión para cada clase
precisions = precision_score(y_true, y_pred, average=None,labels=class_names)  # None para obtener la precisión de cada clase
# Calcular la precisión media total
avg_precision = precision_score(y_true, y_pred, average='macro')  # 'macro' calcula la media sin ponderar
print(class_names)
print("Precisión por clase:", precisions)
print("Precisión media total:", avg_precision)

class_names=y_true.unique()
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_true, y_pred,labels=class_names)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d',xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 1659 1659
# ['student' 'other' 'course' 'faculty' 'project' 'staff' 'department']
# Precisión por clase: [0.41875    0.68644068 0.15097691 0.56666667 0.22580645 0.
#  0.18348624]
# Precisión media total: 0.3188752777416623

# %%
staff_files = result[
    (result['class_model1'] == 'student') 
]
len(staff_files)
# Out:
# 352

# %%
# Filtrar el DataFrame para obtener las filas donde la predicción es 'staff' y la etiqueta verdadera es 'student'
staff_predicted_students = nuevo_df[
    (nuevo_df['predicted_class'] == 'staff') & (nuevo_df['class_model1'] == 'student')
]

# Extraer los nombres de los archivos de estas filas
staff_predicted_student_files = staff_predicted_students['file_name'].tolist()

len(staff_predicted_student_files)
# Out:
# 137

# %% [markdown]
# # -
#
#  Classify the text in this class : student, faculty, course, project, department, staff, other.
#   Reply with only one word:  student, faculty, course, project, department, staff, other.
#
#   ```python
# def creating_promt_5(class_name,text_traindata,text_classification,keywords):
#   # quitamos other de los ejemplos y dejamos que sea como todo lo que no tenga clase como otro
#   class_name=(', ').join(class_name)
#   text_traindata = ('\n\n').join([f" Text:'{tranform_text(text)}' \n class: {label}" for text,label in text_traindata if label!='other'])
#   palabras_clave = ('\n').join([f"{label} keywords are {keys} " for label,keys in keywords])
#   return f" Classify  text into one of 7 class : {class_name}.\n\
#   Reply with only one word:  {class_name}. \n\
#   {palabras_clave} \n\n \
#   Examples: \n\
#   {text_traindata} \n\n\
#   Text: '{tranform_text(text_classification)}' \n\
#   class: "
#
# ```
